# %% [markdown]
# # Singly-Linked-List

# %% [markdown]
# Node class

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

# %% [markdown]
# Linked List Class

# %%
class llist:
    def __init__(self):
        self.head = None

# %% [markdown]
# implement llist insert nodes

# %%
class llist:
    def __init__(self):  #initialize instance
        self.head = None
        
    def list_size(self): #list length
        ct = 0
        if self.head == None :
            return 0
        else:
            temp = self.head
            while temp:
                ct +=1
                temp = temp.next
        return ct
    
    def print_list(self): #print the list
        if self.head == None :
            return "List is Empty"
        else :
            temp = self.head
            while (temp):
                print (temp.data,end="-->")
                temp = temp.next
            print("null")   
        
    def insert_head(self,data): #insertion - add at head
        if self.head == None:
            self.head =Node(data)
        else :
            curr = Node(data)
            curr.next = self.head
            self.head = curr
            
    def insert_last(self,data): #insertion - add at last
        temp = self.head
        while temp.next != None:
            temp = temp.next
        
        new_node = Node(data)
        temp.next = new_node
        
    def insert_after(self,prev,data): #insertion - add before
        new_node = Node(data)
        flag = 0
        if prev == self.head.data :
            new_node.next = self.head.next
            self.head.next = new_node
            flag = 1
        else :
            temp = self.head
            for i in range(self.list_size()):
                temp = temp.next
                if prev == temp.data :
                    new_node.next = temp.next
                    temp.next = new_node
                    flag = 1
                    break
        if flag == 0:
            print ("Previous node not found in list")
            
            
    def del_byvalue(self,data): #same for del by position
        temp = self.head
        flag = 0
        if temp.data == data :
            self.head = temp.next
            temp = None
            flag = 1
        else :
            while temp:
                prev = temp
                temp = temp.next
                if temp.data == data :
                    prev.next = temp.next
                    temp = None
                    flag = 1
                    break
        if flag == 0:
            return "Data to be deleted not found"
        
    def del_last(self):
        temp = self.head
        while temp.next != None:
            prev = temp
            temp = temp.next
            
        prev.next = None
        
    def del_head(self):
        temp = self.head
        self.head = temp.next
        temp = None
                
                     
ll = llist()
ll.insert_head(3)
ll.insert_head(2)
ll.insert_head(1)
ll.print_list()
ll.insert_last(10)
ll.insert_last(11)
ll.print_list()
ll.insert_after(10,7)
ll.print_list()
ll.del_last()            
ll.print_list()
# Out:
# 1-->2-->3-->null
# 1-->2-->3-->10-->11-->null
# 1-->2-->3-->10-->7-->11-->null
# 1-->2-->3-->10-->7-->null

# %% [markdown]
# # Make Yourself easy by  re-editing the Node class

# %%
class Node:
    def __init__(self,data,next = None):
        self.data = data
        self.next = next

class LinkedList:
    def __init__(self):
        self.head = None
        
    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count+=1
            itr = itr.next

        return count
            
            
    def print_list(self):
        if self.head == None:
            print ("List is empty")
        else:
            itr = self.head
            while itr:
                print (itr.data,end = "-->")
                itr = itr.next
            print ("Null")
        
    def insert_beg(self,data):
        if self.head == None:
            self.head = Node(data)
        else:
            newnode = Node(data,self.head)
            self.head = newnode
    
    def insert_end(self,data):
        if self.head == None:
            self.head = Node(data)
        else:
            itr = self.head                      #itr - my var chosen to iterate meaningful than temp
            while itr.next != None:
                itr = itr.next
            itr.next = Node(data)    # see properly
            
    def insert_pos(self,pos,data):
        if pos == 0:
            self.insert_beg(data)  #make use of functions you defined
        else:
            ct = 0
            itr = self.head
            while itr:
                if ct == pos-1:          #see propery
                    newnode = Node(data,itr.next)
                    itr.next = newnode

                itr = itr.next
                ct +=1
                
    def remove_at(self, index):
        if index<0 or index>=self.get_length():
            raise Exception("Invalid Index")

        if index==0:
            self.head = self.head.next
            return

        count = 0
        itr = self.head
        while itr:
            if count == index - 1:
                itr.next = itr.next.next
                break

            itr = itr.next
            count+=1
            
    def insert_after_value(self, data_after, data_to_insert):
        if self.head is None:
            return

        if self.head.data==data_after:
            self.head.next = Node(data_to_insert,self.head.next)
            return

        itr = self.head
        while itr:
            if itr.data == data_after:
                itr.next = Node(data_to_insert, itr.next)
                break

            itr = itr.next

    def remove_by_value(self, data):
        if self.head is None:
            return

        if self.head.data == data:
            self.head = self.head.next
            return

        itr = self.head
        while itr.next:
            if itr.next.data == data:
                itr.next = itr.next.next
                break
            itr = itr.next
                
   
            
            
    
ll = LinkedList()
ll.insert_beg(10)
ll.insert_end(11)
ll.insert_end(12)
ll.print_list()  
ll.insert_pos(0,1)
ll.print_list()
# Out:
# 10-->11-->12-->Null
# 1-->10-->11-->12-->Null

# %% [markdown]
# Create a linked list from a given list

# %%
#cntnution of above code

def insert_values(self, data_list):
        self.head = None
        for data in data_list:
            self.insert_end(data)
            
ll = insert_values(["banana","mango","grapes","orange"])

# %% [markdown]
# # Doubly-Linked-List

# %%
class NodeD:
    def __init__(self,data,next=None,prev=None):
        self.data = data
        self.prev = prev
        self.next = next
        
class DLL:
    def __init__(self):
        self.head = None
        
    def get_len(self):
        if self.head == None:
            return 0
        else:
            itr = self.head
            ct = 0
            while itr :
                itr = itr.next
                ct +=1
        return ct
    
    def get_last_node(self):
        itr = self.head
        while itr.next:
            itr = itr.next
        
        return itr
    
    def print_forward(self):
        if self.head == None:
            print ("Linked List is Empty")
        else:
            itr = self.head
            while itr:
                print (itr.data,end = "<-->")
                itr = itr.next
            print ("null")
        
    def print_backward(self):
        if self.head == None:
            print ("Linked List is Empty")
        else:
            itr = self.get_last_node()
            while itr:
                print (itr.data,end = "<-->")
                itr = itr.prev
            print ("null")
            
    def insert_beg(self,data):
        if self.head == None:
            self.head = NodeD(data)
        else: 
            newnode = NodeD(data,self.head)
            self.head.prev = newnode
            self.head = newnode
    
    def insert_end(self,data):
        if self.head == None:
            self.head = NodeD(data)
        else: 
            itr = self.head
            while itr.next:
                itr = itr.next
            newnode = NodeD(data,None,itr)
            itr.next = newnode
    
    def insert_values(self,arr):
        self.head = None
        for i in arr:
            self.insert_end(i)
            
    def insert_at_pos(self,data,pos):
        if pos < 0 or pos >= self.get_len():
            print ("List index out of range")
        else:
            if pos == 0:
                self.insert_beg(data)
            else:
                ct = 0
                itr = self.head
                while itr:
                    if ct == pos-1:
                        newnode = NodeD(data,itr.next,itr)
                        if newnode.next:
                            newnode.next.prev = newnode
                        itr.next = newnode
                        break
                    itr = itr.next
                    ct +=1
                    
    def remove_at_pos(self,pos):
        if pos < 0 or pos >= self.get_len():
            print ("List index out of range")
        else:
            if pos == 0:
                self.head = self.head.next
                self.head.prev = None
                return
            else:
                ct = 0
                itr = self.head
                while itr:
                    if ct == pos:
                        itr.prev.next = itr.next
                        if itr.next:
                            itr.next.prev = itr.prev
                        break
                    itr = itr.next
                    ct +=1
                            
        
            
d = DLL()
arr = ["A","B","C","D"]
d.insert_values(arr)
d.insert_at_pos(5,2)
d.print_forward()
d.print_backward()
d.remove_at_pos(3)
d.print_forward()
# Out:
# A<-->B<-->5<-->C<-->D<-->null
# D<-->C<-->5<-->B<-->A<-->null
# A<-->B<-->5<-->D<-->null
